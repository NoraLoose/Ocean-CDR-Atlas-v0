# %%
import atlas

# %%
cdr_forcing = "DOR"
vintage = "001"
phase = "deploy"
clobber = False

calc = atlas.global_irf_map(cdr_forcing, vintage)

# %%
# %%time
calc.validate(clobber=clobber)
# Out:
#   0%|          | 0/2314 [00:00<?, ?it/s]
# CPU times: user 42.2 s, sys: 6.86 s, total: 49.1 s
# Wall time: 3min 7s

# %%
df = calc.df_validation
df
# Out:
#                                                     is_cdr_run  \
# case
# smyle.cdr-atlas-v0.control.001                           False
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...        True
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...        True
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...        True
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...        True
# ...                                                        ...
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_038_1...        True
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...        True
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...        True
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...        True
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...        True
#
#                                                     ALK_ALT_CO2_rmse  \
# case
# smyle.cdr-atlas-v0.control.001                              0.224847
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...          0.230523
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...          0.270639
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...          0.225976
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...          0.288906
# ...                                                              ...
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_038_1...          0.260466
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...          0.283162
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...          0.243411
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...          0.278735
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...          0.243958
#
#                                                     ALK_rmse  \
# case
# smyle.cdr-atlas-v0.control.001                      0.224846
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...       NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...       NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...       NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...       NaN
# ...                                                      ...
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_038_1...       NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...       NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...       NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...       NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...       NaN
#
#                                                     DIC_ALT_CO2_rmse  \
# case
# smyle.cdr-atlas-v0.control.001                              0.325688
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...          0.336078
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...          0.315976
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...          0.302304
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...          0.368662
# ...                                                              ...
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_038_1...         30.281244
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...         29.829412
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...         29.981966
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...         30.107902
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...         30.281246
#
#                                                     DIC_rmse  DOC_rmse  \
# case
# smyle.cdr-atlas-v0.control.001                      0.304365  0.045923
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...       NaN       NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...       NaN       NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...       NaN       NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...       NaN       NaN
# ...                                                      ...       ...
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_038_1...       NaN       NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...       NaN       NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...       NaN       NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...       NaN       NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...       NaN       NaN
#
#                                                     DOCr_rmse  DON_rmse  \
# case
# smyle.cdr-atlas-v0.control.001                       0.011091  0.004066
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...        NaN       NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...        NaN       NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...        NaN       NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...        NaN       NaN
# ...                                                       ...       ...
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_038_1...        NaN       NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...        NaN       NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...        NaN       NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...        NaN       NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...        NaN       NaN
#
#                                                     DONr_rmse  DOP_rmse  ...  \
# case                                                                     ...
# smyle.cdr-atlas-v0.control.001                       0.000207  0.000238  ...
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...        NaN       NaN  ...
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...        NaN       NaN  ...
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...        NaN       NaN  ...
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...        NaN       NaN  ...
# ...                                                       ...       ...  ...
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_038_1...        NaN       NaN  ...
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...        NaN       NaN  ...
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...        NaN       NaN  ...
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...        NaN       NaN  ...
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...        NaN       NaN  ...
#
#                                                     diazC_rmse  diazChl_rmse  \
# case
# smyle.cdr-atlas-v0.control.001                        0.000601      0.000147
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...         NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...         NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...         NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...         NaN           NaN
# ...                                                        ...           ...
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_038_1...         NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...         NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...         NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...         NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...         NaN           NaN
#
#                                                      diazFe_rmse  diazP_rmse  \
# case
# smyle.cdr-atlas-v0.control.001                      4.014262e-08    0.000005
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...           NaN         NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...           NaN         NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...           NaN         NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...           NaN         NaN
# ...                                                          ...         ...
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_038_1...           NaN         NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...           NaN         NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...           NaN         NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...           NaN         NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...           NaN         NaN
#
#                                                     spC_rmse  spCaCO3_rmse  \
# case
# smyle.cdr-atlas-v0.control.001                      0.025289      0.005248
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...       NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...       NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...       NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...       NaN           NaN
# ...                                                      ...           ...
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_038_1...       NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...       NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...       NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...       NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...       NaN           NaN
#
#                                                     spChl_rmse     spFe_rmse  \
# case
# smyle.cdr-atlas-v0.control.001                        0.003786  6.857399e-07
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...         NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...         NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...         NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...         NaN           NaN
# ...                                                        ...           ...
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_038_1...         NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...         NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...         NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...         NaN           NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...         NaN           NaN
#
#                                                     spP_rmse  zooC_rmse
# case
# smyle.cdr-atlas-v0.control.001                      0.000216   0.010324
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...       NaN        NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...       NaN        NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...       NaN        NaN
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin...       NaN        NaN
# ...                                                      ...        ...
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_038_1...       NaN        NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...       NaN        NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...       NaN        NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...       NaN        NaN
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1...       NaN        NaN
#
# [2314 rows x 40 columns]

# %%
good = df.loc[df.DIC_ALT_CO2_rmse < 1]
bad = df.loc[df.DIC_ALT_CO2_rmse > 10]

# %%
import matplotlib.pyplot as plt
dfs = calc.df_case_status

dfs.loc[bad.index.to_list()].timestamp_run #.min()
# Out:
# case
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin_001_1999-10-01_00007.001   2025-01-19 11:11:56
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin_003_1999-07-01_00014.001   2025-01-18 23:58:50
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin_006_1999-07-01_00026.001   2025-01-19 09:11:00
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin_007_1999-10-01_00031.001   2025-01-19 11:54:34
# smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin_008_1999-07-01_00034.001   2025-01-19 07:54:11
#                                                                                    ...
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_038_1999-10-01_02755.001         2025-02-08 02:17:07
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1999-01-01_02756.001         2025-02-08 02:18:09
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1999-04-01_02757.001         2025-02-08 02:16:48
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1999-07-01_02758.001         2025-02-08 02:16:59
# smyle.cdr-atlas-v0.glb-dor_Southern_Ocean_039_1999-10-01_02759.001         2025-02-08 02:15:36
# Name: timestamp_run, Length: 1599, dtype: datetime64[ns]

# %%
dfs.loc[good.index.to_list()].timestamp_run.plot()
# Out:
# <Axes: xlabel='case'>

# %%
good.index
# Out:
# Index(['smyle.cdr-atlas-v0.control.001',
#        'smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin_000_1999-01-01_00000.001',
#        'smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin_000_1999-04-01_00001.001',
#        'smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin_000_1999-07-01_00002.001',
#        'smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin_000_1999-10-01_00003.001',
#        'smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin_001_1999-01-01_00004.001',
#        'smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin_001_1999-04-01_00005.001',
#        'smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin_001_1999-07-01_00006.001',
#        'smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin_002_1999-01-01_00008.001',
#        'smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin_002_1999-04-01_00009.001',
#        ...
#        'smyle.cdr-atlas-v0.glb-dor_North_Pacific_basin_040_1999-04-01_00761.001',
#        'smyle.cdr-atlas-v0.glb-dor_North_Pacific_basin_040_1999-07-01_00762.001',
#        'smyle.cdr-atlas-v0.glb-dor_North_Pacific_basin_040_1999-10-01_00763.001',
#        'smyle.cdr-atlas-v0.glb-dor_North_Pacific_basin_041_1999-01-01_00764.001',
#        'smyle.cdr-atlas-v0.glb-dor_North_Pacific_basin_041_1999-04-01_00765.001',
#        'smyle.cdr-atlas-v0.glb-dor_North_Pacific_basin_041_1999-07-01_00766.001',
#        'smyle.cdr-atlas-v0.glb-dor_North_Pacific_basin_041_1999-10-01_00767.001',
#        'smyle.cdr-atlas-v0.glb-dor_North_Pacific_basin_042_1999-01-01_00768.001',
#        'smyle.cdr-atlas-v0.glb-dor_North_Pacific_basin_042_1999-04-01_00769.001',
#        'smyle.cdr-atlas-v0.glb-dor_North_Pacific_basin_042_1999-10-01_00771.001'],
#       dtype='object', name='case', length=715)

# %%
from tqdm.notebook import tqdm
for case in tqdm(bad.index.to_list()):
    calc.clobber_case(case)
# Out:
#   0%|          | 0/1599 [00:00<?, ?it/s]
