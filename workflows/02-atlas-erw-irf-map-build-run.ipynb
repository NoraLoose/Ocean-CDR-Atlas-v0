# %% [markdown]
# # Global IRF Efficiency Map
#
# Generate global map of CDR efficiency using IRF forcing.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import xarray as xr
import matplotlib.pyplot as plt

import atlas

# %% [markdown]
# ## Define experiment and phase

# %%
cdr_forcing = "ERW"
vintage = "001"
phase = "deploy"
clobber = False

# %%
calc = atlas.global_irf_map(cdr_forcing, vintage)

# %% [markdown]
# ## Table of experiments

# %%
calc.df
# Out:
#                                                    blueprint  polygon  \
# case
# smyle.cdr-atlas-v0.control.001                         smyle      NaN
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...     smyle      0.0
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...     smyle      0.0
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...     smyle      0.0
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...     smyle      0.0
# ...                                                      ...      ...
# smyle.cdr-atlas-v0.glb-erw_South_118_1999-10-01...     smyle    118.0
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-01-01...     smyle    119.0
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-04-01...     smyle    119.0
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-07-01...     smyle    119.0
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-10-01...     smyle    119.0
#
#                                                     polygon_master  \
# case
# smyle.cdr-atlas-v0.control.001                                 NaN
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...             0.0
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...             0.0
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...             0.0
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...             0.0
# ...                                                            ...
# smyle.cdr-atlas-v0.glb-erw_South_118_1999-10-01...           468.0
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-01-01...           469.0
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-04-01...           469.0
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-07-01...           469.0
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-10-01...           469.0
#
#                                                                    basin  \
# case
# smyle.cdr-atlas-v0.control.001                                      None
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  North_Atlantic_basin
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  North_Atlantic_basin
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  North_Atlantic_basin
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  North_Atlantic_basin
# ...                                                                  ...
# smyle.cdr-atlas-v0.glb-erw_South_118_1999-10-01...                 South
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-01-01...                 South
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-04-01...                 South
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-07-01...                 South
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-10-01...                 South
#
#                                                    start_date cdr_forcing  \
# case
# smyle.cdr-atlas-v0.control.001                        1999-01        None
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...    1999-01         ERW
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...    1999-04         ERW
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...    1999-07         ERW
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...    1999-10         ERW
# ...                                                       ...         ...
# smyle.cdr-atlas-v0.glb-erw_South_118_1999-10-01...    1999-10         ERW
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-01-01...    1999-01         ERW
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-04-01...    1999-04         ERW
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-07-01...    1999-07         ERW
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-10-01...    1999-10         ERW
#
#                                                                                      cdr_forcing_file  \
# case
# smyle.cdr-atlas-v0.control.001                                                                   None
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  /global/cfs/projectdirs/m4746/Projects/OAE-Eff...
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  /global/cfs/projectdirs/m4746/Projects/OAE-Eff...
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  /global/cfs/projectdirs/m4746/Projects/OAE-Eff...
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  /global/cfs/projectdirs/m4746/Projects/OAE-Eff...
# ...                                                                                               ...
# smyle.cdr-atlas-v0.glb-erw_South_118_1999-10-01...  /global/cfs/projectdirs/m4746/Projects/OAE-Eff...
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-01-01...  /global/cfs/projectdirs/m4746/Projects/OAE-Eff...
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-04-01...  /global/cfs/projectdirs/m4746/Projects/OAE-Eff...
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-07-01...  /global/cfs/projectdirs/m4746/Projects/OAE-Eff...
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-10-01...  /global/cfs/projectdirs/m4746/Projects/OAE-Eff...
#
#                                                                                        simulation_key  \
# case
# smyle.cdr-atlas-v0.control.001                                                               baseline
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  glb-erw_North_Atlantic_basin_000_1999-01-01_00000
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  glb-erw_North_Atlantic_basin_000_1999-04-01_00001
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  glb-erw_North_Atlantic_basin_000_1999-07-01_00002
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  glb-erw_North_Atlantic_basin_000_1999-10-01_00003
# ...                                                                                               ...
# smyle.cdr-atlas-v0.glb-erw_South_118_1999-10-01...                 glb-erw_South_118_1999-10-01_01235
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-01-01...                 glb-erw_South_119_1999-01-01_01236
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-04-01...                 glb-erw_South_119_1999-04-01_01237
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-07-01...                 glb-erw_South_119_1999-07-01_01238
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-10-01...                 glb-erw_South_119_1999-10-01_01239
#
#                                                        refdate  stop_n  \
# case
# smyle.cdr-atlas-v0.control.001                      0347-01-01      16
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  0347-01-01      15
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  0347-04-01      15
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  0347-07-01      15
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  0347-10-01      15
# ...                                                        ...     ...
# smyle.cdr-atlas-v0.glb-erw_South_118_1999-10-01...  0347-10-01      15
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-01-01...  0347-01-01      15
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-04-01...  0347-04-01      15
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-07-01...  0347-07-01      15
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-10-01...  0347-10-01      15
#
#                                                    wallclock  curtail_output
# case
# smyle.cdr-atlas-v0.control.001                      12:00:00           False
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  10:00:00            True
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  10:00:00            True
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  10:00:00            True
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  10:00:00            True
# ...                                                      ...             ...
# smyle.cdr-atlas-v0.glb-erw_South_118_1999-10-01...  10:00:00            True
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-01-01...  10:00:00            True
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-04-01...  10:00:00            True
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-07-01...  10:00:00            True
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-10-01...  10:00:00            True
#
# [1241 rows x 12 columns]

# %% [markdown]
# ## Check status

# %%
# %%time
df = calc.df_case_status
df
# Out:
# CPU times: user 690 ms, sys: 383 ms, total: 1.07 s
# Wall time: 57.8 s
#                                                     build  submitted  \
# case
# smyle.cdr-atlas-v0.control.001                       True      False
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...   True       True
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...   True      False
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...   True      False
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...   True      False
# ...                                                   ...        ...
# smyle.cdr-atlas-v0.glb-erw_South_118_1999-10-01...   True      False
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-01-01...   True      False
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-04-01...   True      False
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-07-01...   True      False
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-10-01...   True      False
#
#                                                     run_completed  archive  \
# case
# smyle.cdr-atlas-v0.control.001                              False    False
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...           True     True
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...          False    False
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...          False    False
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...          False    False
# ...                                                           ...      ...
# smyle.cdr-atlas-v0.glb-erw_South_118_1999-10-01...          False    False
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-01-01...          False    False
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-04-01...          False    False
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-07-01...          False    False
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-10-01...          False    False
#
#                                                     error  error_count  \
# case
# smyle.cdr-atlas-v0.control.001                      False            0
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...   True            2
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  False            0
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  False            0
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...  False            0
# ...                                                   ...          ...
# smyle.cdr-atlas-v0.glb-erw_South_118_1999-10-01...  False            0
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-01-01...  False            0
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-04-01...  False            0
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-07-01...  False            0
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-10-01...  False            0
#
#                                                          timestamp_run JobId  \
# case
# smyle.cdr-atlas-v0.control.001                                     NaT  None
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin... 2025-06-20 20:21:26  None
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...                 NaT  None
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...                 NaT  None
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...                 NaT  None
# ...                                                                ...   ...
# smyle.cdr-atlas-v0.glb-erw_South_118_1999-10-01...                 NaT  None
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-01-01...                 NaT  None
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-04-01...                 NaT  None
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-07-01...                 NaT  None
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-10-01...                 NaT  None
#
#                                                    JobState  Queued  \
# case
# smyle.cdr-atlas-v0.control.001                         None   False
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...     None   False
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...     None   False
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...     None   False
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...     None   False
# ...                                                     ...     ...
# smyle.cdr-atlas-v0.glb-erw_South_118_1999-10-01...     None   False
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-01-01...     None   False
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-04-01...     None   False
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-07-01...     None   False
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-10-01...     None   False
#
#                                                     yr_per_day  pe-hr_per_yr
# case
# smyle.cdr-atlas-v0.control.001                             NaN           NaN
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...        57.0        377.26
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...         NaN           NaN
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...         NaN           NaN
# smyle.cdr-atlas-v0.glb-erw_North_Atlantic_basin...         NaN           NaN
# ...                                                        ...           ...
# smyle.cdr-atlas-v0.glb-erw_South_118_1999-10-01...         NaN           NaN
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-01-01...         NaN           NaN
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-04-01...         NaN           NaN
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-07-01...         NaN           NaN
# smyle.cdr-atlas-v0.glb-erw_South_119_1999-10-01...         NaN           NaN
#
# [1241 rows x 12 columns]

# %% [markdown]
# ## Build the model for each experiment

# %%
clobber_list = calc.check_cases()
clobber_list
# Out:
# []

# %%
len(clobber_list)
# Out:
# 0

# %%
calc.build(phase=phase, clobber=clobber, clobber_list=clobber_list)
# Out:
# Submitted batch job 39958961
# Submitted batch job 39958963
# Submitted batch job 39958965
# Submitted batch job 39958966
# Submitted batch job 39958967
# Submitted batch job 39958968
# Submitted batch job 39958969
# Submitted batch job 39958970
# Submitted batch job 39958972
# Submitted batch job 39958973
# Submitted batch job 39958974
# Submitted batch job 39958975
# Submitted batch job 39958976
# Submitted batch job 39958977
# Submitted batch job 39958978
# Submitted batch job 39958979
# Submitted batch job 39958980
# Submitted batch job 39958981
# Submitted batch job 39958982
# Submitted batch job 39958983
# Submitted batch job 39958984
# Submitted batch job 39958985
# Submitted batch job 39958986
# Submitted batch job 39958987
# Submitted batch job 39958988
# Submitted batch job 39958989
# Submitted batch job 39958990
# Submitted batch job 39958991
# Submitted batch job 39958992
# Submitted batch job 39958993
# Submitted batch job 39958994
# Submitted batch job 39958995
# Submitted batch job 39958996
# Submitted batch job 39958997
# Submitted batch job 39958998
# Submitted batch job 39958999
# Submitted batch job 39959000
# Submitted batch job 39959001
# Submitted batch job 39959002
# Submitted batch job 39959003
# Submitted batch job 39959004
# Submitted batch job 39959005
# Submitted batch job 39959006
# Submitted batch job 39959007

# %% [markdown]
# ## Run the simulations

# %%
n_jobs = calc.compute(n_bundle=140, bundle_queue="regular")
# Out:
# waiting on 44 build(s)
