# %%
import xarray as xr

# %%
ds = xr.open_dataset(
    "s3://carbonplan-oae-efficiency/v2/cumulative_FG_CO2_percent.zarr/", engine="zarr", chunks={}
)
ds
# Out:
# <xarray.Dataset> Size: 6MB
# Dimensions:                    (time: 180, polygon: 690, season: 4,
#                                 dist2center: 3)
# Coordinates:
#   * dist2center                (dist2center) float32 12B 5e+05 1e+06 2e+06
#   * polygon                    (polygon) int32 3kB 0 1 2 3 4 ... 686 687 688 689
#   * season                     (season) <U8 128B 'Januaray' ... 'October'
#   * time                       (time) float64 1kB 0.0 1.0 2.0 ... 178.0 179.0
# Data variables:
#     FG_CO2_percent_cumulative  (time, polygon, season, dist2center) float32 6MB dask.array<chunksize=(180, 690, 1, 3), meta=np.ndarray>

# %%
ds.dist2center.attrs
# Out:
# {'unit': 'm'}

# %%
ds.FG_CO2_percent_cumulative.attrs
# Out:
# {'detail': 'Cumulative percent of CO2 uptake, within a time step and distance to center'}

# %%
ds.data_vars
# Out:
# Data variables:
#     FG_CO2_percent_cumulative  (time, polygon, season, dist2center) float32 6MB dask.array<chunksize=(180, 690, 1, 3), meta=np.ndarray>

# %%
dt["0"]["DIC"].sel(band="experimental").isel(month=0, year=0, polygon_id=1).plot(
    col="injection_date", robust=True
)
