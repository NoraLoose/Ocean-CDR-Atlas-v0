# %%
import xarray as xr

# %%
path = "/pscratch/sd/a/abanihi/dor/cumulative_FG_CO2_percent.zarr"

# %%
ds = xr.open_zarr(path)
ds
# Out:
# <xarray.Dataset> Size: 6MB
# Dimensions:                    (elapsed_time: 180, polygon_id: 690,
#                                 intervention_month: 4, dist2center: 3)
# Coordinates:
#   * dist2center                (dist2center) float64 24B 5e+05 1e+06 2e+06
#   * elapsed_time               (elapsed_time) float64 1kB 0.0 1.0 ... 179.0
#   * intervention_month         (intervention_month) float64 32B 1.0 4.0 7.0 10.0
#   * polygon_id                 (polygon_id) float64 6kB 0.0 1.0 ... 688.0 689.0
# Data variables:
#     FG_CO2_percent_cumulative  (elapsed_time, polygon_id, intervention_month, dist2center) float32 6MB dask.array<chunksize=(180, 1, 1, 3), meta=np.ndarray>
# Attributes:
#     description:  Cumulative percent of CO2 uptake, within a time step and di...
#     long_name:    Cumulative FG CO2 percent
#     units:        percent

# %%
ds.FG_CO2_percent_cumulative.isel(polygon_id=2, intervention_month=3).plot(col='dist2center')
