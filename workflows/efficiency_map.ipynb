# %%
import xarray as xr

# %%
import pop_tools
# Out:
# /global/common/software/m4632/conda/cworthy/lib/python3.11/site-packages/pop_tools/__init__.py:4: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import DistributionNotFound, get_distribution

# %%
grid = pop_tools.get_grid("POP_gx1v7")

# %%
base_path = "/global/cfs/projectdirs/m4746/Datasets/Ocean-CDR-Atlas-v0/DOR-Efficiency-Map/research-grade-compressed/"

# %%
ds_eff = xr.open_dataset(f"{base_path}/DOR_equil_fraction_maps_alltime.nc")

# %%
ds_eff
# Out:
# <xarray.Dataset> Size: 710MB
# Dimensions:         (season: 4, N_month: 180, nlat: 384, nlon: 320)
# Coordinates:
#   * season          (season) <U7 112B 'January' 'April' 'July' 'October'
#   * N_month         (N_month) int64 1kB 0 1 2 3 4 5 ... 174 175 176 177 178 179
#     TLONG           (nlat, nlon) float64 983kB ...
#     TLAT            (nlat, nlon) float64 983kB ...
# Dimensions without coordinates: nlat, nlon
# Data variables:
#     DOR_efficiency  (season, N_month, nlat, nlon) float64 708MB ...

# %%
ds_eff.DOR_efficiency.isel(season=0, N_month=0).plot()

# %%
ds_eff.DOR_efficiency.isel(season=0, N_month=-1).plot()
