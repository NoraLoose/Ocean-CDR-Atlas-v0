# %% [markdown]
# # glb-dor_North_Atlantic_basin_030_1999-10-01_00123
#
# ## Simulation details
# - Case: smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin_030_1999-10-01_00123.001
# - Basin: North_Atlantic_basin
# - Polygon: 30.0
# - Start date: 1999-10

# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
zarr_store = "/path/to/zarr/store"

# %%
# Parameters
zarr_store = "/global/cfs/projectdirs/m4746/Projects/Ocean-CDR-Atlas-v0/data/validation/smyle.cdr-atlas-v0.glb-dor_North_Atlantic_basin_030_1999-10-01_00123.001.validation.zarr"

# %%
# %%time
ds_o = xr.open_zarr(zarr_store).compute()
ds_o
# Out:
# CPU times: user 640 ms, sys: 463 ms, total: 1.1 s
# Wall time: 1.45 s
# <xarray.Dataset> Size: 2MB
# Dimensions:            (nlat: 384, nlon: 320, time: 180)
# Coordinates:
#     TLAT               float64 8B -79.22
#     TLONG              float64 8B 320.6
#     ULAT               float64 8B -78.95
#     ULONG              float64 8B 321.1
#   * time               (time) object 1kB 0347-11-01 00:00:00 ... 0362-10-01 0...
#     z_t                float32 4B 500.0
# Dimensions without coordinates: nlat, nlon
# Data variables:
#     ALK_ALT_CO2_diff   (nlat, nlon) float32 492kB nan nan nan ... nan nan nan
#     ALK_ALT_CO2_rmse   (time) float64 1kB 0.01393 0.03483 ... 0.1071 0.1073
#     DIC_ALT_CO2_diff   (nlat, nlon) float32 492kB nan nan nan ... nan nan nan
#     DIC_ALT_CO2_rmse   (time) float64 1kB 0.0247 0.07121 ... 0.1543 0.1682
#     ECOSYS_IFRAC_diff  (nlat, nlon) float32 492kB nan nan nan ... nan nan nan
# ...

# %%
variables = [v[:-5] for v in ds_o.variables if "_rmse" in v]

# %%
plt.rcParams.update({'figure.max_open_warning': 0})

for v in variables:
    fig, axs = plt.subplots(1, 2, figsize=(15, 6))
    ds_o[f"{v}_rmse"].plot(ax=axs[0])   
    ds_o[f"{v}_diff"].plot(ax=axs[1])
    plt.suptitle(v, fontweight="bold")
